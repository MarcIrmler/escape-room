# %%
from tkinter import *
from PIL import ImageTk, Image
import os

# %%
# define rooms and items

couch = {
    "name": "couch",
    "type": "furniture",
}

door_a = {
    "name": "door a",
    "type": "door",
}

key_a = {
    "name": "key for door a",
    "type": "key",
    "target": door_a,
}

piano = {
    "name": "piano",
    "type": "furniture",
}

game_room = {
    "name": "game room",
    "type": "room",
}

outside = {
  "name": "outside"
}

#this dictionaries below are related to beedroom_1

bedroom_1 = {
    "name": "bedroom_1",
    "type": "room",
}

queen_bed = {
    "name": "queen_bed",
    "type": "furniture",
}

door_b = {
    "name": "door b",
    "type": "door",
}

key_b = {
    "name": "key for door b",
    "type": "key",
    "target": door_b,
}


door_c = {
    "name": "door c",
    "type": "door",
}

#this dictionaries below are related to beedroom_2

bedroom_2 = {
    "name": "bedroom_2",
    "type": "room",
}

dresser = {
    "name": "dresser",
    "type": "furniture",
}

double_bed = {
    "name": "double_bed",
    "type": "furniture",
}

key_c = {
    "name": "key for door c",
    "type": "key",
    "target": door_c,
}

door_d = {
    "name": "door d",
    "type": "door",
}

key_d = {
    "name": "key for door d",
    "type": "key",
    "target": door_d,
}

#this dictionaries below are related to the living room

living_room = {
    "name": "living_room",
    "type": "room",
}

dining_table = {
    "name": "dining_table",
    "type": "furniture",
}


all_rooms = [game_room, bedroom_1, bedroom_2, living_room, outside]

all_doors = [door_a, door_b, door_c, door_d]

# define which items/rooms are related

object_relations = {
    "game room": [couch, piano, door_a],
    "piano": [key_a],
    "outside": [door_d],
    "door a": [game_room, bedroom_1],
    "bedroom_1": [queen_bed, door_b, door_c],
    "queen_bed": [key_b],
    "door c": [bedroom_1, living_room],
    "door b": [bedroom_1, bedroom_2],
    "living_room": [dining_table, door_c, door_d],
    "door d": [outside, living_room],
    "bedroom_2":[double_bed, dresser, door_b],
    "dresser":[key_d],
    "double_bed":[key_c]

}


# define game state. Do not directly change this dict. 
# Instead, when a new game starts, make a copy of this
# dict and use the copy to store gameplay state. This 
# way you can replay the game multiple times.

INIT_GAME_STATE = {
    "current_room": game_room,
    "keys_collected": [],
    "target_room": outside
}

# %%
root = Tk()
frame = Frame(root)
frame.pack()

w = 800 # width for the Tk root
h = 800 # height for the Tk root

ws = root.winfo_screenwidth() # width of the screen
hs = root.winfo_screenheight() # height of the screen

x = (ws/2) - (w/2)
y = (hs/2) - (h/2)
root.geometry('%dx%d+%d+%d' % (w, h, x, y))

img = ImageTk.PhotoImage(Image.open("Capture.PNG"))
root.title("Escape room game")
panel = Label(root, image = img)
panel.pack(side = "bottom", fill = "both", expand = "yes")

def quit():
    root.destroy()
    exit()
    
button = Button()
button['text'] ="Quit game"
button['command'] = quit
button.pack()
button.place(x=450, y = 20)


def start():
    
    v = StringVar()
    v.set("You wake up on a couch and find yourself \n in a strange house with no windows which \n you have never been to before. \n You don't remember why you are here and what \n had happened before. You feel some \n unknown danger is approaching and you \n must get out of the house, NOW!")
    Label(root, textvariable=v, bg="red", fg="white", height = 150, width= 150).pack()
    game_state = INIT_GAME_STATE.copy()
    button = Button()
    button['text'] ="do it"
    button['command'] = play_room1(game_state["current_room"])
    button.pack()
    button.place(x=578, y = 180)
    
    
    
def play_room1(room):
    l = StringVar()
    button = Button()
    button['text'] ="do it"
    button['command'] = getTextInput
    button.pack()
    button.place(x=578, y = 180)
    game_state["current room"] = room
    Label(root, textvariable=l, bg="red", fg="white", height = 150, width= 150).pack()
    l.set("You are now in " + room["name"])
    w = Label(root, text="Type in explore or examine")
    w.place(x=200, y = 180)
    
    global E1
    E1 = Entry(root, bd =5)
    E1.place(x=375, y = 176)
   
def getTextInput():
    result=E1.get()
    print(result)
        
    
#def play_room(room):
    """
    Play a room. First check if the room being played is the target room.
    If it is, the game will end with success. Otherwise, let player either 
    explore (list all items in this room) or examine an item found here.
    """
    #game_state["current_room"] = room
    
    #if(game_state["current_room"] == game_state["target_room"]):
        
        #print("Congrats! You escaped the room!")
    #else:
        #print("You are now in " + room["name"])
        #intended_action = input("What would you like to do? Type 'explore' or 'examine'?").strip()
        #if intended_action == "explore":
            #explore_room(room)
            #play_room(room)
        #elif intended_action == "examine":
            #examine_item(input("What would you like to examine?").strip())
        #else:
            #print("Not sure what you mean. Type 'explore' or 'examine'.")
            #play_room(room)
        



button1 = Button()
button1['text'] ="Start game"
button1['command'] = start 
button1.pack()
button1.place(x=250, y = 20)

game_state = INIT_GAME_STATE.copy()

root.mainloop()
